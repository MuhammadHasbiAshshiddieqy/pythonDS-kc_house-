# %% [markdown]
# <img src="img/make ai logo.png" width="180" height="360" align="right"/>

# %% [markdown]
# ### Welcome to the Final Project of Class 1
# In this Final Project you will explore and analyze data about House Pricing in Kings County, USA. We know that there are so much variables that can create different prices, such as how many bedrooms, how big living rooms is, and many more. We will explore together, but you should explore more wilder. Do you ready? Let's go !

# %% [markdown]
# ### Load and Combine Dataset

# %% [markdown]
# First of all, we should import package there are needed for analyze data. For now we are using **Pandas**, **Numpy**, **Matplotlib**, and **Seaborn**, don't forget with **Pandas Profiling** too.

# %%
# import package that are needed from above

import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# After importing the package, of course we need to import dataset itself. Let's import!

# %%
# import dataset, dataset name is kc_house_data.csv in folder 'data', named it with 'df'

df = pd.read_csv('Data/kc_house_data.csv')

# %% [markdown]
# How is our data after imported? Check it out !

# %%
# print first 8 data in the df

df.head(8)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# ...

# %% [markdown]
# After knowing our data, let's see how many rows and columns in our data.

# %%
# how many rows and columns?

df.shape
# Out:
# (21613, 21)

# %% [markdown]
# There are much rows and columns, right? Now it's time to check datatype and missing values. Is it any missing values?

# %%
# check about datatypes and missing values

df.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# Don't forget with check what column in our data is about. Is it some strange names?

# %%
# you know what to do, right?

df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Investigate Our Data

# %% [markdown]
# After you have done with import data and know how big your data is, now let's analyze with some statistic data.

# %% [markdown]
# Double-click __here__ for the definition for each column.
#
# <!-- Your answer is below:
# This is about Housing Prices with many columns, such as:
#
# **id** :
# a notation for a house
#
# **date** :
# Date house was sold
#
# **price** :
# Price is prediction target
#
# **bedrooms** :
# Number of Bedrooms/House
#
# **bathrooms** :
# Number of bathrooms/House
#
# **sqft_living** :
# square footage of the home
#
# **sqft_lot** :
# square footage of the lot
#
# **floors** :
# Total floors (levels) in house
#
# **waterfront** :
# House which has a view to a waterfront
#
# **view** :
# Has been viewed
#
# **condition** :
# How good the condition is ( Overall )
#
# **grade** :
# overall grade given to the housing unit, based on King County grading system
#
# **sqft_above** :
# square footage of house apart from basement
#
# **sqft_basement** :
# square footage of the basement
#
# **yr_built** :
# Built Year
#
# **yr_renovated** :
# Year when house was renovated
#
# **zipcode** :
# zip
#
# **lat** :
# Latitude coordinate
#
# **long** :
# Longitude coordinate
#
# **sqft_living15** :
# Living room area in 2015(implies-- some renovations) This might or might not have affected the lotsize area
#
# **sqft_lot15** :
# lotSize area in 2015(implies-- some renovations)
# -->

# %%
# Check statistical value for every column

df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
# For better analysis, check it with Pandas Profiling

pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# After you get some values, I guess that you are confused with so many numbers inside, and get some e- , so here is solution for changed e- into full number.

# %%
pd.set_option('float_format', '{:f}'.format)

# %% [markdown]
# Actually when you run code above, you are changing all the numerical value into float and e- into full number.
#
# Check statistical value again.

# %%
# Check statistical value again

df.describe()
# Out:
#                      id          price     bedrooms    bathrooms  sqft_living  \
# count      21613.000000   21613.000000 21613.000000 21613.000000 21613.000000
# mean  4580301520.864988  540088.141767     3.370842     2.114757  2079.899736
# std   2876565571.312057  367127.196483     0.930062     0.770163   918.440897
# min      1000102.000000   75000.000000     0.000000     0.000000   290.000000
# 25%   2123049194.000000  321950.000000     3.000000     1.750000  1427.000000
# 50%   3904930410.000000  450000.000000     3.000000     2.250000  1910.000000
# 75%   7308900445.000000  645000.000000     4.000000     2.500000  2550.000000
# max   9900000190.000000 7700000.000000    33.000000     8.000000 13540.000000
#
#             sqft_lot       floors   waterfront         view    condition  \
# count   21613.000000 21613.000000 21613.000000 21613.000000 21613.000000
# mean    15106.967566     1.494309     0.007542     0.234303     3.409430
# ...

# %% [markdown]
# Looks better, right? So, let's find insight so we can get into Domain Knowledge, based on our data in statistic.

# %% [markdown]
# Example :
# - In target variable, **price** there are no outlier, but there is some kind more space between **min** and **Q1** than **Q3** and **max** with average of house price is 540,000 but getting median 450,000 . So in some case price is very expensive, some case there are some cheaper price.

# %% [markdown]
# Find minimum 5 insight from data.

# %%
df.corr()['price']
# Out:
# id              -0.016762
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# Name: price, dtype: float64

# %% [markdown]
# 1. Berdasarkan skala kondisi bangunan yang diberikan. Terdapat bangunan dengan kondisi dibawah rata-rata yang belum pernah direnovasi dan sudah pernah direnovasi, di antaranya adalah kondisi yang termasuk dalam kategori outlier. Jadi, beberapa bangunan memiliki kondisi yang buruk atau tidak layak untuk dijual. Walaupun terdapat bangunan dengan kondisi di bawah rata rata, namun persebaran data paling banyak terdapat pada kondisi dengan nilai antara 2.7586864636509123  sampai  4.060172556383327. Hal ini menunjukan bahwa kondisi mayoritas bangunan terdapat pada nilai 3 dan 4.
#    Kondisi memiliki nilai antara 1 sampai 5. Apabila dikonversi, maka dapat diberikan nilai kondisi sebagai berikut :
#    1 = tidak layak;
#    2 = kurang layak;
#    3 = layak;
#    4 = lebih layak;
#    5 = sangat layak.
#    Berdasarkan persebaran data dan mode dari kondisi bangunan, maka dapat disimpulkan bahwa mayoritas bangunan adalah bangunan dengan kondisi layak. Walaupun kondisi dari mayoritas rumah adalah layak, namun hal ini tidak berpengaruh banyak pada penentuan harga rumah.

# %%
IQR = 4.0-3.0
minim = 3.0-1.5*IQR
maxim = 4.0+1.5*IQR
print("Mode : ", df['condition'].mode().values[0])
print("Data dikatakan outlier apabila data <", minim," atau data >", maxim)
# Out:
# Mode :  3
# Data dikatakan outlier apabila data < 1.5  atau data > 5.5

# %%
print("Persebaran data paling banyak terdapat antara ", df['condition'].mean()-df['condition'].std()," sampai ", df['condition'].mean()+df['condition'].std())
# Out:
# Persebaran data paling banyak terdapat antara  2.7586864636509123  sampai  4.060172556383327

# %%
sumConditionVal = df['condition'].value_counts()
sns.scatterplot(y=list(sumConditionVal),x=list(sumConditionVal.index))
plt.xlabel("Condition")
plt.ylabel("Count")
plt.show()

# %%
sns.scatterplot(x='condition', y='price', data=df, hue='price', size='price')
plt.show()

# %% [markdown]
# 2. Berdasarkan analisa statistika terhadap luas dari rumah (sqft_living). Terdapat 4.659% outlier pada variabel 'sqft_living'. Hal ini menunjukan bahwa kita dapat menggunakan rerata(mean) untuk menjadi tendensi sentral. Luas dari rumah memiliki keterkaitan yang tinggi terhadap luas dari ruang atas ('sqft_above'). Hal ini menunjukkan bahwa semakin luas rumah, maka akan semakin luas ruangan atas. Data dari 'sqft_living' memiliki kecondongan ke arah kanan (condong positif), hal ini dapat dilihat berdasarkan nilai mean yang lebih besar daripada nilai modus.
#     Berdasarkan plot sqft_above terhadap price, dapat disimpulkan bahwa luas dari ruang atas cenderung meningkat dan berpengaruh terhadap harga dari rumah.

# %%
df['sqft_living'].describe()
# Out:
# count   21613.000000
# mean     2079.899736
# std       918.440897
# min       290.000000
# 25%      1427.000000
# 50%      1910.000000
# 75%      2550.000000
# max     13540.000000
# Name: sqft_living, dtype: float64

# %%
df.corr()['sqft_living']
# Out:
# id              -0.012258
# price            0.702035
# bedrooms         0.576671
# bathrooms        0.754665
# sqft_living      1.000000
# sqft_lot         0.172826
# floors           0.353949
# waterfront       0.103818
# view             0.284611
# condition       -0.058753
# grade            0.762704
# sqft_above       0.876597
# sqft_basement    0.435043
# yr_built         0.318049
# yr_renovated     0.055363
# zipcode         -0.199430
# lat              0.052529
# long             0.240223
# sqft_living15    0.756420
# sqft_lot15       0.183286
# Name: sqft_living, dtype: float64

# %%
sns.scatterplot(x='sqft_living', y='sqft_above', data=df, hue='price', size='price')
plt.show()

# %%
sns.scatterplot(x='sqft_above', y='price', data=df, hue='price', size='price')
plt.show()

# %% [markdown]
# 3. Berdasarkan analisa statistika terhadap hubungan antara harga dengan luas dari rumah. Dapat disimpulkan bahwa semakin luas rumah, maka semakin mahal harga rumah. Walaupun begitu, peningkatan harga rumah tidak terlalu besar pada beberapa kasus. Berdasarkan plot yang telah dibuat terdapat rumah dengan ukuran luas, namun memiliki harga yang rendah. Persebaran data harga rumah paling banyak terdapat antara  172960.94528382958  sampai  907215.3382492292.

# %%
df.corr()["price"]
# Out:
# id              -0.016762
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# Name: price, dtype: float64

# %%
sns.scatterplot(x='sqft_living', y='price', data=df, hue='price', size='price')
plt.show()

# %% [markdown]
# 4. Tahun pembuatan bangunan tidak dapat menjadi penentu harga sebuah rumah. Karena rumah yang dibangun lebih baru, belum tentu memiliki fitur lain yang lebih baik.

# %%
sns.scatterplot(x=df['yr_built'],y=df['price'])
plt.show()

# %% [markdown]
# 5. Berdasarkan tahun renovasi. 95.8 % dari yr_renovated bernilai 0, artinya mayoritas semua rumah belum pernah direnovasi. Dapat disimpulkan bahwa renovasi rumah tidak dapat menjadi tolak ukur penentu harga.

# %%
df_renovated = df[df['yr_renovated']!=0]
df_neverRenov = df[df['yr_renovated']==0]

# %%
df_neverRenov.shape[0]/df.shape[0]
# Out:
# 0.9577106371165502

# %% [markdown]
# Do you find many insight? I hope so, since that there are so many thing to explore about.

# %% [markdown]
# After finding insight, now it's time to analyze each columns you need to understand, but first you can drop many columns that no need to analyze.

# %%
df = df.drop(['id','date','zipcode','lat','long'], axis=1)
df.head()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot   floors  \
# 0 221900.000000         3   1.000000         1180      5650 1.000000
# 1 538000.000000         3   2.250000         2570      7242 2.000000
# 2 180000.000000         2   1.000000          770     10000 1.000000
# 3 604000.000000         4   3.000000         1960      5000 1.000000
# 4 510000.000000         3   2.000000         1680      8080 1.000000
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15
# 0             0           1340        5650
# ...

# %% [markdown]
# After removed 5 columns, so there are still much columns to understand, right?

# %% [markdown]
# Maybe before we analyze each column, better if we check correlation from each columns and target itself.

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,cmap='RdBu')

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(method='spearman'),annot=True,cmap='RdBu')

# %% [markdown]
# Did you find any pattern of that color? Or you get some interesting insight?

# %% [raw]
# # Type here
#
# 1. Berdasarkan tabel korelasi, dapat disimpulkan bahwa kondisi rumah adalah salah satu fitur yang paling tidak berpengaruh dalam penentuan harga rumah
#
# 2. Berdasarkan tabel korelasi, dapat disimpulkan bahwa luas rumah(sqft_living) sangat berpengaruh pada penentuan harga rumah. Dengan hubungan sebanding atau dapat diartikan, semakin luas rumah, maka akan semakin mahal harganya.

# %% [markdown]
# After you check correlation, it's time to check every columns and maybe you can get another insight.

# %% [markdown]
# ##### Example

# %%
ax = sns.countplot(x='grade', data=df)
plt.title('Distribution of House Price from Grade')
plt.show()

# %% [markdown]
# ###### Explanation :
# From this visualization we can get information, that the most house is in **Grade 7**, while grade is from 1 until 13.
#
# We still don't know if :
# - more number in grade means more expensive or
# - less number means more expensive.
#
# So let's find out.

# %%
sns.scatterplot(x='grade', y='price', data=df)
plt.title('Scatter Plot Between Grade and Price')
plt.show()

# %% [markdown]
# The answer is, no, whil actually the correlation is slightly positive but, in some case when price is 100,000 there are in grade 6 until 12. So it doesn't mean that *more grade equals more price.*

# %% [markdown]
# Now it's your turn to analyze with your sense. Let's do it.

# %%
sns.distplot(df['sqft_living'], kde=False)
plt.show()

# %%
print("Persebaran data paling banyak terdapat antara ", df['sqft_living'].mean()-df['sqft_living'].std()," sampai ", df['sqft_living'].mean()+df['sqft_living'].std())
# Out:
# Persebaran data paling banyak terdapat antara  1161.4588392230257  sampai  2998.340633316649

# %%
# Type your answer here

sns.scatterplot(x='sqft_living', y='price', data=df)
plt.title('Scatter Plot Between Square Footage of Home and Price')
plt.show()

# %% [raw]
# Dapat disimpulkan bahwa luas dari bangunan sangat berpengaruh pada penentuan harga dari rumah tersebut. Hal ini dapat dilihat dengan meningkatnya harga rumah bersama dengan peningkatan luas dari bangunan.

# %% [markdown]
# ### Find Categorical and Numerical

# %% [markdown]
# If you find some unusual visualization above, it means that you are not separate between data **categorical** and **numerical**.
#
# Remembered it? Yeah, while in some visualization is using categorical data only, numerical data only, or both of them.
#
# Let's divide them into categorical and numerical. What columns is categorical and what kind is numerical?
# - data_cat for data categorical
# - data_num for data numerical

# %%
df.head()
# Out:
#           price  bedrooms  bathrooms  sqft_living  sqft_lot   floors  \
# 0 221900.000000         3   1.000000         1180      5650 1.000000
# 1 538000.000000         3   2.250000         2570      7242 2.000000
# 2 180000.000000         2   1.000000          770     10000 1.000000
# 3 604000.000000         4   3.000000         1960      5000 1.000000
# 4 510000.000000         3   2.000000         1680      8080 1.000000
#
#    waterfront  view  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0           0     0          3      7        1180              0      1955
# 1           0     0          3      7        2170            400      1951
# 2           0     0          3      6         770              0      1933
# 3           0     0          5      7        1050            910      1965
# 4           0     0          3      8        1680              0      1987
#
#    yr_renovated  sqft_living15  sqft_lot15
# 0             0           1340        5650
# ...

# %%
# Type here for answer

data_cat = df[['waterfront', 'condition']]

# %%
data_cat.head()
# Out:
#    waterfront  condition
# 0           0          3
# 1           0          3
# 2           0          3
# 3           0          5
# 4           0          3

# %%
data_num = df.drop(['waterfront', 'condition', 'price'], axis=1)

# %%
data_num.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot   floors  view  grade  \
# 0         3   1.000000         1180      5650 1.000000     0      7
# 1         3   2.250000         2570      7242 2.000000     0      7
# 2         2   1.000000          770     10000 1.000000     0      6
# 3         4   3.000000         1960      5000 1.000000     0      7
# 4         3   2.000000         1680      8080 1.000000     0      8
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  sqft_living15  \
# 0        1180              0      1955             0           1340
# 1        2170            400      1951          1991           1690
# 2         770              0      1933             0           2720
# 3        1050            910      1965             0           1360
# 4        1680              0      1987             0           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %% [markdown]
# #### Numerical Data Normalization
# It's your turn to normalize your data for better understanding of it. Now it's numerical time.

# %%
# Type here for normalize

from sklearn.preprocessing import MinMaxScaler
min_max_scaler = MinMaxScaler()

data_normal_num = min_max_scaler.fit_transform(data_num)
data_normal_num = pd.DataFrame(data_normal_num, columns=data_num.columns)

# %%
data_normal_num.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot   floors     view    grade  \
# 0  0.090909   0.125000     0.067170  0.003108 0.000000 0.000000 0.500000
# 1  0.090909   0.281250     0.172075  0.004072 0.400000 0.000000 0.500000
# 2  0.060606   0.125000     0.036226  0.005743 0.000000 0.000000 0.416667
# 3  0.121212   0.375000     0.126038  0.002714 0.000000 0.000000 0.500000
# 4  0.090909   0.250000     0.104906  0.004579 0.000000 0.000000 0.583333
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  sqft_living15  \
# 0    0.097588       0.000000  0.478261      0.000000       0.161934
# 1    0.206140       0.082988  0.443478      0.988089       0.222165
# 2    0.052632       0.000000  0.286957      0.000000       0.399415
# 3    0.083333       0.188797  0.565217      0.000000       0.165376
# 4    0.152412       0.000000  0.756522      0.000000       0.241094
#
#    sqft_lot15
# 0    0.005742
# 1    0.008027
# 2    0.008513
# 3    0.004996
# 4    0.007871

# %% [raw]
# MinMaxScaler digunakan untuk mengurangi range data yang terlalu jauh.

# %% [markdown]
# #### Categorical Data Normalization
# Now for categorical data, let's normalize it !

# %%
# Type here for normalize

from sklearn.preprocessing import LabelEncoder
Lencoder = LabelEncoder()

data_cat_norm = data_cat.copy()
length = data_cat_norm.shape[1]
col = data_cat_norm.columns
for i in range (length):
    a = Lencoder.fit_transform(data_cat_norm.iloc[:,i:i+1])
    a = pd.DataFrame(a, columns=[col[i]+'new'])
    data_cat_norm = data_cat_norm.join(a)
# Out:
# C:\Users\USER\Anaconda3\envs\MachineLearningEnv\lib\site-packages\sklearn\preprocessing\label.py:235: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
data_cat_norm.head(10)
# Out:
#    waterfront  condition  waterfrontnew  conditionnew
# 0           0          3              0             2
# 1           0          3              0             2
# 2           0          3              0             2
# 3           0          5              0             4
# 4           0          3              0             2
# 5           0          3              0             2
# 6           0          3              0             2
# 7           0          3              0             2
# 8           0          3              0             2
# 9           0          3              0             2

# %% [raw]
# LabelEncoder digunakan untuk mempermudah pengolahan data. LabelEncoder digunakan karena ragam data tidak terlalu banyak.

# %% [markdown]
# #### Combined and Save Your Data

# %% [markdown]
# After you normalize categorical and numerical, don't forget to combined all of your data and save it into csv format file.

# %%
# Type here
data_norm = data_normal_num.copy()
data_norm = data_norm.join(data_cat_norm[['waterfrontnew', 'conditionnew']])
data_norm = data_norm.join(df[['price']])

# %%
data_norm.head(10)
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot   floors     view    grade  \
# 0  0.090909   0.125000     0.067170  0.003108 0.000000 0.000000 0.500000
# 1  0.090909   0.281250     0.172075  0.004072 0.400000 0.000000 0.500000
# 2  0.060606   0.125000     0.036226  0.005743 0.000000 0.000000 0.416667
# 3  0.121212   0.375000     0.126038  0.002714 0.000000 0.000000 0.500000
# 4  0.090909   0.250000     0.104906  0.004579 0.000000 0.000000 0.583333
# 5  0.121212   0.562500     0.387170  0.061429 0.000000 0.000000 0.833333
# 6  0.090909   0.281250     0.107547  0.003816 0.400000 0.000000 0.500000
# 7  0.090909   0.187500     0.058113  0.005567 0.000000 0.000000 0.500000
# 8  0.090909   0.125000     0.112453  0.004210 0.000000 0.000000 0.500000
# 9  0.090909   0.312500     0.120755  0.003659 0.400000 0.000000 0.500000
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  sqft_living15  \
# 0    0.097588       0.000000  0.478261      0.000000       0.161934
# ...

# %% [markdown]
# ### Linear Model

# %% [markdown]
# Define what is your $x$ and $y$ and split into training and testing split.
# For :
# - One variable $x$
# - Many variable $x$
# - All variable $x$

# %%
# Type here
Xone = data_norm[['sqft_living']] #dipilih berdasarkan korelasi
Xmany = data_norm[['sqft_living', 'grade', 'sqft_above']] #dipilih berdasarkan korelasi
Xall = data_norm.drop(['price'], axis = 1)
y = data_norm['price']

# %%
Xone.head()
# Out:
#    sqft_living
# 0     0.067170
# 1     0.172075
# 2     0.036226
# 3     0.126038
# 4     0.104906

# %%
Xmany.head()
# Out:
#    sqft_living    grade  sqft_above
# 0     0.067170 0.500000    0.097588
# 1     0.172075 0.500000    0.206140
# 2     0.036226 0.416667    0.052632
# 3     0.126038 0.500000    0.083333
# 4     0.104906 0.583333    0.152412

# %%
Xall.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot   floors     view    grade  \
# 0  0.090909   0.125000     0.067170  0.003108 0.000000 0.000000 0.500000
# 1  0.090909   0.281250     0.172075  0.004072 0.400000 0.000000 0.500000
# 2  0.060606   0.125000     0.036226  0.005743 0.000000 0.000000 0.416667
# 3  0.121212   0.375000     0.126038  0.002714 0.000000 0.000000 0.500000
# 4  0.090909   0.250000     0.104906  0.004579 0.000000 0.000000 0.583333
#
#    sqft_above  sqft_basement  yr_built  yr_renovated  sqft_living15  \
# 0    0.097588       0.000000  0.478261      0.000000       0.161934
# 1    0.206140       0.082988  0.443478      0.988089       0.222165
# 2    0.052632       0.000000  0.286957      0.000000       0.399415
# 3    0.083333       0.188797  0.565217      0.000000       0.165376
# 4    0.152412       0.000000  0.756522      0.000000       0.241094
#
#    sqft_lot15  waterfrontnew  conditionnew
# 0    0.005742              0             2
# ...

# %%
y.head()
# Out:
# 0   221900.000000
# 1   538000.000000
# 2   180000.000000
# 3   604000.000000
# 4   510000.000000
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
Xone_train, Xone_test, yone_train, yone_test = train_test_split(Xone,y,test_size=0.25,random_state = 45)
Xmany_train, Xmany_test, ymany_train, ymany_test = train_test_split(Xmany,y,test_size=0.25,random_state = 45)
Xall_train, Xall_test, yall_train, yall_test = train_test_split(Xall,y,test_size=0.25,random_state = 45)

# %% [markdown]
# After that, define function for Linear Model, fit and predict

# %%
from sklearn.linear_model import LinearRegression

# %%
model_reg_one = LinearRegression()
model_reg_many = LinearRegression()
model_reg_all = LinearRegression()

# %%
model_reg_one.fit(Xone_train, yone_train)
model_reg_many.fit(Xmany_train, ymany_train)
model_reg_all.fit(Xall_train, yall_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Get the formula for each model and score of them.
#
# **Example**:
# price = 10 * grade + 5 * condition

# %%
print("one feature")
print("Price = ", model_reg_one.coef_[0]," * ", Xone.columns[0]," + ", model_reg_one.intercept_)
# Out:
# one feature
# Price =  3706224.396904624  *  sqft_living  +  38943.86084180995

# %%
print("many feature")
formula = ""
for i in range(len(Xmany.columns)):
    formula = formula + str(model_reg_many.coef_[i])+" * "+ Xmany.columns[i] + " + "
print("Price = ",formula, model_reg_one.intercept_)
# Out:
# many feature
# Price =  3141845.7257270752 * sqft_living + 1309270.3765656292 * grade + -742038.4170702138 * sqft_above +  38943.86084180995

# %%
print("all feature")
formula = ""
for i in range(len(Xall.columns)):
    formula = formula + str(model_reg_all.coef_[i])+" * "+ Xall.columns[i] + " + "
print("Price = ",formula, model_reg_all.intercept_)
# Out:
# all feature
# Price =  -1254547.4157959358 * bedrooms + 347103.4192459004 * bathrooms + 795345.0693870115 * sqft_living + 59690.145584113576 * sqft_lot + 79641.70509095548 * floors + 173912.0529928486 * view + 1431995.5042840373 * grade + 875332.7566154475 * sqft_above + 530142.6201338139 * sqft_basement + -413892.58881846647 * yr_built + 33628.516820964054 * yr_renovated + 173863.1170184257 * sqft_living15 + -564717.3730537363 * sqft_lot15 + 533229.959314406 * waterfrontnew + 19276.627834860385 * conditionnew +  -364762.9920069692

# %%
#predict one feature

price_one_pred = model_reg_one.predict(Xone_test)
pd.DataFrame({'actual':yone_test,'prediction':price_one_pred}).head()
# Out:
#               actual    prediction
# 17055  630000.000000 715854.278993
# 2488   425000.000000 388587.671871
# 1808   850000.000000 718651.429482
# 10638  520000.000000 522850.895306
# 9172  1234000.000000 701868.526552

# %%
#predict many feature

price_many_pred = model_reg_many.predict(Xmany_test)
pd.DataFrame({'actual':ymany_test,'prediction':price_many_pred}).head()
# Out:
#               actual    prediction
# 17055  630000.000000 760716.096933
# 2488   425000.000000 360269.179892
# 1808   850000.000000 653167.797925
# 10638  520000.000000 489546.121004
# 9172  1234000.000000 712168.047366

# %%
#predict all feature

price_all_pred = model_reg_all.predict(Xall_test)
pd.DataFrame({'actual':yall_test,'prediction':price_all_pred}).head()
# Out:
#               actual    prediction
# 17055  630000.000000 681016.262526
# 2488   425000.000000 273695.134422
# 1808   850000.000000 608128.617963
# 10638  520000.000000 361027.499242
# 9172  1234000.000000 952423.305371

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# score for one feature
print("one feature")
print("MSE : ",mean_squared_error(yone_test, price_one_pred))
print("MAE : ",mean_absolute_error(yone_test, price_one_pred))
print("R2 : ",r2_score(yone_test, price_one_pred))
# Out:
# one feature
# MSE :  70975092470.0326
# MAE :  173773.42049021574
# R2 :  0.497043443051604

# %%
# score for many feature
print("many feature")
print("MSE : ",mean_squared_error(ymany_test, price_many_pred))
print("MAE : ",mean_absolute_error(ymany_test, price_many_pred))
print("R2 : ",r2_score(ymany_test, price_many_pred))
# Out:
# many feature
# MSE :  64209405855.552
# MAE :  162876.45386855872
# R2 :  0.5449876771002989

# %%
# score for all feature
print("all feature")
print("MSE : ",mean_squared_error(yall_test, price_all_pred))
print("MAE : ",mean_absolute_error(yall_test, price_all_pred))
print("R2 : ",r2_score(yall_test, price_all_pred))
# Out:
# all feature
# MSE :  48948299782.69219
# MAE :  141504.43570895115
# R2 :  0.6531336914062427

# %% [markdown]
# ### Conclusion
# After you are working with this data, what is your conclusion?

# %% [raw]
# Kesimpulan dari pengerjaan study case 2 ini adalah pengambilan satu fitur dengan korelasi tertinggi belum tentu dapat melakukan prediksi yang baik. Hal ini dapat dilihat dengan perbandingan model antara model dengan satu fitur, banyak fitur, dan semua fitur. sqft_living memang memiliki korelasi yang tinggi terhadap harga rumah, namun pembuatan model dengan satu fitur akan memiliki masalah pada beberapa kasus
